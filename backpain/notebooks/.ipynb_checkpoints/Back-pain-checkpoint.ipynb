# %%
from sklearn import datasets, neighbors, metrics,grid_search, cross_validation
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from pandas.io import sql
import sqlite3
# %matplotlib inline


conn = sqlite3.connect('../backpain.db')

data = pd.read_csv('../Dataset_spine.csv', low_memory=False)
data.head()
data.to_sql('spine',
            con=conn,
            if_exists='replace',
            index=False)
df = pd.read_sql("SELECT "
                "pelvic_incidence, pelvic_tilt,lumbar_lordosis_angle,sacral_slope,"
                "pelvic_radius,degree_spondylolisthesis,pelvic_slope,direct_tilt,"
                "thoracic_slope,cervical_tilt,sacrum_angle,scoliosis_slope,"
                  "case when Class_att = 'Abnormal' then 1 else 0 end as classification "
                  "FROM spine s", con=conn)

columns = ['pelvic_incidence', 'pelvic_tilt','lumbar_lordosis_angle','sacral_slope','pelvic_radius','degree_spondylolisthesis','pelvic_slope','direct_tilt','thoracic_slope','cervical_tilt','sacrum_angle','scoliosis_slope']
cmap = {'0': 'r', '1': 'g'}
df['cclassification'] = df.classification.apply(lambda x: cmap[str(x)])
plot = df.plot('pelvic_incidence', 'pelvic_tilt', kind='scatter', c=df.cclassification)
# plot.legend(df.classification, loc='best')

# %%
plot = df.plot('pelvic_incidence', 'lumbar_lordosis_angle', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('pelvic_incidence', 'sacral_slope', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('pelvic_incidence', 'pelvic_radius', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('pelvic_incidence', 'degree_spondylolisthesis', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('pelvic_incidence', 'pelvic_slope', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('pelvic_incidence', 'direct_tilt', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('pelvic_incidence', 'thoracic_slope', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('pelvic_incidence', 'cervical_tilt', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('pelvic_incidence', 'sacrum_angle', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('pelvic_incidence', 'scoliosis_slope', kind='scatter', c=df.cclassification)

# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
X_train, X_test, y_train, y_test = train_test_split(df[columns], df.classification, test_size=0.33, random_state=42)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)
print accuracy_score(y_test, pred)

x = [i for i in range(1, 50)]
kf = cross_validation.KFold(len(df), n_folds = 5, shuffle=True)
gs = grid_search.GridSearchCV(
    estimator=neighbors.KNeighborsClassifier(),
    param_grid={'n_neighbors': x, 'weights':['uniform', 'distance']},
    cv=kf
)
gs.fit(df[columns], df.classification)
gs.grid_scores_
# Out:
# 0.805825242718
# [mean: 0.76774, std: 0.03762, params: {'n_neighbors': 1, 'weights': 'uniform'},
#  mean: 0.76774, std: 0.03762, params: {'n_neighbors': 1, 'weights': 'distance'},
#  mean: 0.76129, std: 0.04376, params: {'n_neighbors': 2, 'weights': 'uniform'},
#  mean: 0.76774, std: 0.03762, params: {'n_neighbors': 2, 'weights': 'distance'},
#  mean: 0.79032, std: 0.04446, params: {'n_neighbors': 3, 'weights': 'uniform'},
#  mean: 0.79032, std: 0.04446, params: {'n_neighbors': 3, 'weights': 'distance'},
#  mean: 0.79677, std: 0.04849, params: {'n_neighbors': 4, 'weights': 'uniform'},
#  mean: 0.78387, std: 0.04741, params: {'n_neighbors': 4, 'weights': 'distance'},
#  mean: 0.79677, std: 0.06086, params: {'n_neighbors': 5, 'weights': 'uniform'},
#  mean: 0.79355, std: 0.05895, params: {'n_neighbors': 5, 'weights': 'distance'},
#  mean: 0.79355, std: 0.05895, params: {'n_neighbors': 6, 'weights': 'uniform'},
# ...

# %%
from sklearn.cross_validation import cross_val_score
scores = cross_val_score(gs, X_train, y_train, scoring='roc_auc', cv=5)
print('CV AUC {}, Average AUC {}'.format(scores, scores.mean()))
# Out:
# <class 'sklearn.grid_search.GridSearchCV'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-da714feb9a08> in <module>()
#       1 from sklearn.cross_validation import cross_val_score
#       2 print type(gs)
# ----> 3 scores = cross_val_score(gs, X_train, y_train, scoring='roc_auc', cv=5)
#       4 print('CV AUC {}, Average AUC {}'.format(scores, scores.mean()))
#
# /Users/nullpointer0x00/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1569                                               train, test, verbose, None,
#    1570                                               fit_params)
# -> 1571                       for train, test in cv)
#    1572     return np.array(scores)[:, 0]
#    1573
#
# ...

# %%
from sklearn.tree import export_graphviz
from os import system 
def build_tree_image(model):
    dotfile = open("tree.dot", 'w')
    export_graphviz(model,
                              out_file = dotfile,
                              feature_names = columns)
    dotfile.close()
    system("dot -Tpng tree.dot -o tree.png")
    

model = DecisionTreeClassifier(
                max_depth = 16,
                min_samples_leaf = 5)

model.fit(df[columns], df.classification)
build_tree_image(model)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 20)
    
model.fit(df[columns], df.classification)

features = df[columns]
feature_importances = model.feature_importances_
print feature_importances
features_df = pd.DataFrame({'Features': columns, 'Importance Score': feature_importances})
features_df.sort_values('Importance Score', inplace=True, ascending=False)

features_df.head(12)
# Out:
# [ 0.10150682  0.08321053  0.0690798   0.0915611   0.14085203  0.25872231
#   0.02102543  0.04635231  0.04362484  0.05912206  0.05311698  0.03182577]
#                     Features  Importance Score
# 5   degree_spondylolisthesis          0.258722
# 4              pelvic_radius          0.140852
# 0           pelvic_incidence          0.101507
# 3               sacral_slope          0.091561
# 1                pelvic_tilt          0.083211
# 2      lumbar_lordosis_angle          0.069080
# 9              cervical_tilt          0.059122
# 10              sacrum_angle          0.053117
# 7                direct_tilt          0.046352
# 8             thoracic_slope          0.043625
# 11           scoliosis_slope          0.031826
# 6               pelvic_slope          0.021025

# %%
plot = df.plot('scoliosis_slope', 'pelvic_slope', kind='scatter', c=df.cclassification)

# %%
plot = df.plot('degree_spondylolisthesis', 'pelvic_slope', kind='scatter', c=df.cclassification)
